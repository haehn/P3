# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 90305639259365950
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 500367360
# locality {
#   bus_id: 4
#   numa_node: 3
#   links {
#     link {
#       device_id: 1
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 2
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 3
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 4
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 5
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 6
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 7
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 4658196017817591230
# physical_device_desc: "device: 0, name: A100-SXM4-40GB, pci bus id: 0000:07:00.0, compute capability: 8.0"
# , name: "/device:GPU:1"
# device_type: "GPU"
# memory_limit: 39688798208
# locality {
#   bus_id: 4
#   numa_node: 3
#   links {
#     link {
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 2
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 3
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 4
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 5
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 6
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 7
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 9756632379565352068
# physical_device_desc: "device: 1, name: A100-SXM4-40GB, pci bus id: 0000:0f:00.0, compute capability: 8.0"
# , name: "/device:GPU:2"
# device_type: "GPU"
# memory_limit: 39688798208
# locality {
#   bus_id: 2
#   numa_node: 1
#   links {
#     link {
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 1
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 3
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 4
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 5
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 6
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 7
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 1340099882071663815
# physical_device_desc: "device: 2, name: A100-SXM4-40GB, pci bus id: 0000:47:00.0, compute capability: 8.0"
# , name: "/device:GPU:3"
# device_type: "GPU"
# memory_limit: 39688798208
# locality {
#   bus_id: 2
#   numa_node: 1
#   links {
#     link {
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 1
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 2
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 4
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 5
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 6
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 7
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 12746787059688133143
# physical_device_desc: "device: 3, name: A100-SXM4-40GB, pci bus id: 0000:4e:00.0, compute capability: 8.0"
# , name: "/device:GPU:4"
# device_type: "GPU"
# memory_limit: 39688798208
# locality {
#   bus_id: 8
#   numa_node: 7
#   links {
#     link {
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 1
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 2
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 3
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 5
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 6
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 7
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 18384004826988168806
# physical_device_desc: "device: 4, name: A100-SXM4-40GB, pci bus id: 0000:87:00.0, compute capability: 8.0"
# , name: "/device:GPU:5"
# device_type: "GPU"
# memory_limit: 39688798208
# locality {
#   bus_id: 8
#   numa_node: 7
#   links {
#     link {
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 1
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 2
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 3
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 4
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 6
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 7
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 4482534229384725131
# physical_device_desc: "device: 5, name: A100-SXM4-40GB, pci bus id: 0000:90:00.0, compute capability: 8.0"
# , name: "/device:GPU:6"
# device_type: "GPU"
# memory_limit: 39688798208
# locality {
#   bus_id: 6
#   numa_node: 5
#   links {
#     link {
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 1
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 2
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 3
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 4
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 5
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 7
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 11239958342036767442
# physical_device_desc: "device: 6, name: A100-SXM4-40GB, pci bus id: 0000:b7:00.0, compute capability: 8.0"
# , name: "/device:GPU:7"
# device_type: "GPU"
# memory_limit: 39688798208
# locality {
#   bus_id: 6
#   numa_node: 5
#   links {
#     link {
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 1
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 2
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 3
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 4
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 5
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 6
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 850790013866195785
# physical_device_desc: "device: 7, name: A100-SXM4-40GB, pci bus id: 0000:bd:00.0, compute capability: 8.0"
# ]
# 2021-07-15 09:38:12.820973: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-07-15 09:38:12.836669: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-07-15 09:38:13.981811: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:07:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:13.984073: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:0f:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:13.986166: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:47:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:13.988244: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 3 with properties:
# pciBusID: 0000:4e:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:13.990323: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 4 with properties:
# pciBusID: 0000:87:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:13.992408: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 5 with properties:
# pciBusID: 0000:90:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:13.994486: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 6 with properties:
# pciBusID: 0000:b7:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:13.996726: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 7 with properties:
# pciBusID: 0000:bd:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:13.996760: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-07-15 09:38:13.999437: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2021-07-15 09:38:13.999464: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2021-07-15 09:38:14.000355: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2021-07-15 09:38:14.000795: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2021-07-15 09:38:14.002717: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2021-07-15 09:38:14.003448: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2021-07-15 09:38:14.003819: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2021-07-15 09:38:14.035228: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0, 1, 2, 3, 4, 5, 6, 7
# 2021-07-15 09:38:14.035257: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-07-15 09:38:16.874576: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-07-15 09:38:16.874625: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2 3 4 5 6 7
# 2021-07-15 09:38:16.874633: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N Y Y Y Y Y Y Y
# 2021-07-15 09:38:16.874640: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   Y N Y Y Y Y Y Y
# 2021-07-15 09:38:16.874644: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   Y Y N Y Y Y Y Y
# 2021-07-15 09:38:16.874647: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 3:   Y Y Y N Y Y Y Y
# 2021-07-15 09:38:16.874651: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 4:   Y Y Y Y N Y Y Y
# 2021-07-15 09:38:16.874655: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 5:   Y Y Y Y Y N Y Y
# 2021-07-15 09:38:16.874658: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 6:   Y Y Y Y Y Y N Y
# 2021-07-15 09:38:16.874662: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 7:   Y Y Y Y Y Y Y N
# 2021-07-15 09:38:16.909299: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/device:GPU:0 with 477 MB memory) -> physical GPU (device: 0, name: A100-SXM4-40GB, pci bus id: 0000:07:00.0, compute capability: 8.0)
# 2021-07-15 09:38:16.913337: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/device:GPU:1 with 37850 MB memory) -> physical GPU (device: 1, name: A100-SXM4-40GB, pci bus id: 0000:0f:00.0, compute capability: 8.0)
# 2021-07-15 09:38:16.916222: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/device:GPU:2 with 37850 MB memory) -> physical GPU (device: 2, name: A100-SXM4-40GB, pci bus id: 0000:47:00.0, compute capability: 8.0)
# 2021-07-15 09:38:16.918906: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/device:GPU:3 with 37850 MB memory) -> physical GPU (device: 3, name: A100-SXM4-40GB, pci bus id: 0000:4e:00.0, compute capability: 8.0)
# 2021-07-15 09:38:16.921616: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/device:GPU:4 with 37850 MB memory) -> physical GPU (device: 4, name: A100-SXM4-40GB, pci bus id: 0000:87:00.0, compute capability: 8.0)
# 2021-07-15 09:38:16.924301: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/device:GPU:5 with 37850 MB memory) -> physical GPU (device: 5, name: A100-SXM4-40GB, pci bus id: 0000:90:00.0, compute capability: 8.0)
# 2021-07-15 09:38:16.927024: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/device:GPU:6 with 37850 MB memory) -> physical GPU (device: 6, name: A100-SXM4-40GB, pci bus id: 0000:b7:00.0, compute capability: 8.0)
# 2021-07-15 09:38:16.929701: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/device:GPU:7 with 37850 MB memory) -> physical GPU (device: 7, name: A100-SXM4-40GB, pci bus id: 0000:bd:00.0, compute capability: 8.0)

# %%
from ai_benchmark import AIBenchmark
benchmark = AIBenchmark()
results = benchmark.run()
# Out:
# >>   AI-Benchmark-v.0.1.2
# >>   Let the AI Games begin..
# 2021-07-15 09:38:33.291366: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:07:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:33.293488: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:0f:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:33.295578: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:47:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:33.297918: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 3 with properties:
# pciBusID: 0000:4e:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:33.300000: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 4 with properties:
# pciBusID: 0000:87:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:33.302120: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 5 with properties:
# pciBusID: 0000:90:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:33.304211: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 6 with properties:
# pciBusID: 0000:b7:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:33.306291: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 7 with properties:
# pciBusID: 0000:bd:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:33.337320: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0, 1, 2, 3, 4, 5, 6, 7
# 2021-07-15 09:38:33.337492: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-07-15 09:38:33.337498: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2 3 4 5 6 7
# 2021-07-15 09:38:33.337503: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N Y Y Y Y Y Y Y
# 2021-07-15 09:38:33.337507: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   Y N Y Y Y Y Y Y
# 2021-07-15 09:38:33.337511: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   Y Y N Y Y Y Y Y
# 2021-07-15 09:38:33.337514: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 3:   Y Y Y N Y Y Y Y
# 2021-07-15 09:38:33.337518: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 4:   Y Y Y Y N Y Y Y
# 2021-07-15 09:38:33.337522: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 5:   Y Y Y Y Y N Y Y
# 2021-07-15 09:38:33.337525: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 6:   Y Y Y Y Y Y N Y
# 2021-07-15 09:38:33.337529: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 7:   Y Y Y Y Y Y Y N
# 2021-07-15 09:38:33.355245: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/device:GPU:0 with 477 MB memory) -> physical GPU (device: 0, name: A100-SXM4-40GB, pci bus id: 0000:07:00.0, compute capability: 8.0)
# 2021-07-15 09:38:33.357337: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/device:GPU:1 with 37850 MB memory) -> physical GPU (device: 1, name: A100-SXM4-40GB, pci bus id: 0000:0f:00.0, compute capability: 8.0)
# 2021-07-15 09:38:33.359411: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/device:GPU:2 with 37850 MB memory) -> physical GPU (device: 2, name: A100-SXM4-40GB, pci bus id: 0000:47:00.0, compute capability: 8.0)
# 2021-07-15 09:38:33.361482: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/device:GPU:3 with 37850 MB memory) -> physical GPU (device: 3, name: A100-SXM4-40GB, pci bus id: 0000:4e:00.0, compute capability: 8.0)
# 2021-07-15 09:38:33.363551: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/device:GPU:4 with 37850 MB memory) -> physical GPU (device: 4, name: A100-SXM4-40GB, pci bus id: 0000:87:00.0, compute capability: 8.0)
# 2021-07-15 09:38:33.365613: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/device:GPU:5 with 37850 MB memory) -> physical GPU (device: 5, name: A100-SXM4-40GB, pci bus id: 0000:90:00.0, compute capability: 8.0)
# 2021-07-15 09:38:33.367671: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/device:GPU:6 with 37850 MB memory) -> physical GPU (device: 6, name: A100-SXM4-40GB, pci bus id: 0000:b7:00.0, compute capability: 8.0)
# 2021-07-15 09:38:33.369744: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/device:GPU:7 with 37850 MB memory) -> physical GPU (device: 7, name: A100-SXM4-40GB, pci bus id: 0000:bd:00.0, compute capability: 8.0)
# 2021-07-15 09:38:33.371382: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:07:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:33.373436: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:0f:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:33.375702: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:47:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:33.378006: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 3 with properties:
# pciBusID: 0000:4e:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:33.380384: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 4 with properties:
# pciBusID: 0000:87:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:33.382485: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 5 with properties:
# pciBusID: 0000:90:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:33.384574: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 6 with properties:
# pciBusID: 0000:b7:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:33.386667: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 7 with properties:
# pciBusID: 0000:bd:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:33.418076: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0, 1, 2, 3, 4, 5, 6, 7
# 2021-07-15 09:38:33.418251: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-07-15 09:38:33.418259: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2 3 4 5 6 7
# 2021-07-15 09:38:33.418265: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N Y Y Y Y Y Y Y
# 2021-07-15 09:38:33.418269: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   Y N Y Y Y Y Y Y
# 2021-07-15 09:38:33.418273: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   Y Y N Y Y Y Y Y
# 2021-07-15 09:38:33.418278: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 3:   Y Y Y N Y Y Y Y
# 2021-07-15 09:38:33.418282: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 4:   Y Y Y Y N Y Y Y
# 2021-07-15 09:38:33.418286: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 5:   Y Y Y Y Y N Y Y
# 2021-07-15 09:38:33.418289: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 6:   Y Y Y Y Y Y N Y
# 2021-07-15 09:38:33.418293: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 7:   Y Y Y Y Y Y Y N
# 2021-07-15 09:38:33.435425: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/device:GPU:0 with 477 MB memory) -> physical GPU (device: 0, name: A100-SXM4-40GB, pci bus id: 0000:07:00.0, compute capability: 8.0)
# 2021-07-15 09:38:33.437524: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/device:GPU:1 with 37850 MB memory) -> physical GPU (device: 1, name: A100-SXM4-40GB, pci bus id: 0000:0f:00.0, compute capability: 8.0)
# 2021-07-15 09:38:33.439600: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/device:GPU:2 with 37850 MB memory) -> physical GPU (device: 2, name: A100-SXM4-40GB, pci bus id: 0000:47:00.0, compute capability: 8.0)
# 2021-07-15 09:38:33.441680: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/device:GPU:3 with 37850 MB memory) -> physical GPU (device: 3, name: A100-SXM4-40GB, pci bus id: 0000:4e:00.0, compute capability: 8.0)
# 2021-07-15 09:38:33.443751: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/device:GPU:4 with 37850 MB memory) -> physical GPU (device: 4, name: A100-SXM4-40GB, pci bus id: 0000:87:00.0, compute capability: 8.0)
# 2021-07-15 09:38:33.446034: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/device:GPU:5 with 37850 MB memory) -> physical GPU (device: 5, name: A100-SXM4-40GB, pci bus id: 0000:90:00.0, compute capability: 8.0)
# 2021-07-15 09:38:33.448111: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/device:GPU:6 with 37850 MB memory) -> physical GPU (device: 6, name: A100-SXM4-40GB, pci bus id: 0000:b7:00.0, compute capability: 8.0)
# 2021-07-15 09:38:33.450203: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/device:GPU:7 with 37850 MB memory) -> physical GPU (device: 7, name: A100-SXM4-40GB, pci bus id: 0000:bd:00.0, compute capability: 8.0)
# 2021-07-15 09:38:33.452090: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:07:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:33.454149: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:0f:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:33.456195: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:47:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:33.458525: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 3 with properties:
# pciBusID: 0000:4e:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:33.460575: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 4 with properties:
# pciBusID: 0000:87:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:33.462623: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 5 with properties:
# pciBusID: 0000:90:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:33.464848: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 6 with properties:
# pciBusID: 0000:b7:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:33.467464: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 7 with properties:
# pciBusID: 0000:bd:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:33.498967: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0, 1, 2, 3, 4, 5, 6, 7
# 2021-07-15 09:38:33.499049: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-07-15 09:38:33.499055: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2 3 4 5 6 7
# 2021-07-15 09:38:33.499059: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N Y Y Y Y Y Y Y
# 2021-07-15 09:38:33.499063: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   Y N Y Y Y Y Y Y
# 2021-07-15 09:38:33.499066: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   Y Y N Y Y Y Y Y
# 2021-07-15 09:38:33.499070: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 3:   Y Y Y N Y Y Y Y
# 2021-07-15 09:38:33.499074: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 4:   Y Y Y Y N Y Y Y
# 2021-07-15 09:38:33.499077: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 5:   Y Y Y Y Y N Y Y
# 2021-07-15 09:38:33.499081: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 6:   Y Y Y Y Y Y N Y
# 2021-07-15 09:38:33.499084: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 7:   Y Y Y Y Y Y Y N
# 2021-07-15 09:38:33.516464: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/device:GPU:0 with 477 MB memory) -> physical GPU (device: 0, name: A100-SXM4-40GB, pci bus id: 0000:07:00.0, compute capability: 8.0)
# 2021-07-15 09:38:33.518533: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/device:GPU:1 with 37850 MB memory) -> physical GPU (device: 1, name: A100-SXM4-40GB, pci bus id: 0000:0f:00.0, compute capability: 8.0)
# 2021-07-15 09:38:33.520591: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/device:GPU:2 with 37850 MB memory) -> physical GPU (device: 2, name: A100-SXM4-40GB, pci bus id: 0000:47:00.0, compute capability: 8.0)
# 2021-07-15 09:38:33.522657: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/device:GPU:3 with 37850 MB memory) -> physical GPU (device: 3, name: A100-SXM4-40GB, pci bus id: 0000:4e:00.0, compute capability: 8.0)
# 2021-07-15 09:38:33.524714: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/device:GPU:4 with 37850 MB memory) -> physical GPU (device: 4, name: A100-SXM4-40GB, pci bus id: 0000:87:00.0, compute capability: 8.0)
# 2021-07-15 09:38:33.526780: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/device:GPU:5 with 37850 MB memory) -> physical GPU (device: 5, name: A100-SXM4-40GB, pci bus id: 0000:90:00.0, compute capability: 8.0)
# 2021-07-15 09:38:33.528841: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/device:GPU:6 with 37850 MB memory) -> physical GPU (device: 6, name: A100-SXM4-40GB, pci bus id: 0000:b7:00.0, compute capability: 8.0)
# 2021-07-15 09:38:33.530902: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/device:GPU:7 with 37850 MB memory) -> physical GPU (device: 7, name: A100-SXM4-40GB, pci bus id: 0000:bd:00.0, compute capability: 8.0)
# *  TF Version: 2.5.0
# *  Platform: Linux-5.4.0-64-generic-x86_64-with-glibc2.31
# *  CPU: N/A
# *  CPU RAM: 2016 GB
# *  GPU/0: A100-SXM4-40GB
# *  GPU RAM: 0.5 GB
# *  GPU/1: A100-SXM4-40GB
# *  GPU RAM: 37.0 GB
# *  GPU/2: A100-SXM4-40GB
# *  GPU RAM: 37.0 GB
# *  GPU/3: A100-SXM4-40GB
# *  GPU RAM: 37.0 GB
# *  GPU/4: A100-SXM4-40GB
# *  GPU RAM: 37.0 GB
# *  GPU/5: A100-SXM4-40GB
# *  GPU RAM: 37.0 GB
# *  GPU/6: A100-SXM4-40GB
# *  GPU RAM: 37.0 GB
# *  GPU/7: A100-SXM4-40GB
# *  GPU RAM: 37.0 GB
# *  CUDA Version: 10.1
# *  CUDA Build: V10.1.243
#
# The benchmark is running...
# The tests might take up to 20 minutes
# Please don't interrupt the script
#
# 1/19. MobileNet-V2
# 2021-07-15 09:38:40.171485: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:07:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:40.173616: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:0f:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:40.175703: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:47:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:40.177809: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 3 with properties:
# pciBusID: 0000:4e:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:40.179898: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 4 with properties:
# pciBusID: 0000:87:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:40.181984: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 5 with properties:
# pciBusID: 0000:90:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:40.184075: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 6 with properties:
# pciBusID: 0000:b7:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:40.186160: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 7 with properties:
# pciBusID: 0000:bd:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:40.221050: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0, 1, 2, 3, 4, 5, 6, 7
# 2021-07-15 09:38:40.223178: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:07:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:40.225251: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:0f:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:40.227299: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 2 with properties:
# pciBusID: 0000:47:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:40.229358: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 3 with properties:
# pciBusID: 0000:4e:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:40.231409: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 4 with properties:
# pciBusID: 0000:87:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:40.233466: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 5 with properties:
# pciBusID: 0000:90:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:40.235514: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 6 with properties:
# pciBusID: 0000:b7:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:40.237566: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 7 with properties:
# pciBusID: 0000:bd:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2021-07-15 09:38:40.269845: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0, 1, 2, 3, 4, 5, 6, 7
# 2021-07-15 09:38:40.270026: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-07-15 09:38:40.270034: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1 2 3 4 5 6 7
# 2021-07-15 09:38:40.270039: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N Y Y Y Y Y Y Y
# 2021-07-15 09:38:40.270043: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   Y N Y Y Y Y Y Y
# 2021-07-15 09:38:40.270046: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 2:   Y Y N Y Y Y Y Y
# 2021-07-15 09:38:40.270050: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 3:   Y Y Y N Y Y Y Y
# 2021-07-15 09:38:40.270054: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 4:   Y Y Y Y N Y Y Y
# 2021-07-15 09:38:40.270058: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 5:   Y Y Y Y Y N Y Y
# 2021-07-15 09:38:40.270062: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 6:   Y Y Y Y Y Y N Y
# 2021-07-15 09:38:40.270065: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 7:   Y Y Y Y Y Y Y N
# 2021-07-15 09:38:40.287619: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 477 MB memory) -> physical GPU (device: 0, name: A100-SXM4-40GB, pci bus id: 0000:07:00.0, compute capability: 8.0)
# 2021-07-15 09:38:40.289706: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 37850 MB memory) -> physical GPU (device: 1, name: A100-SXM4-40GB, pci bus id: 0000:0f:00.0, compute capability: 8.0)
# 2021-07-15 09:38:40.291779: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:2 with 37850 MB memory) -> physical GPU (device: 2, name: A100-SXM4-40GB, pci bus id: 0000:47:00.0, compute capability: 8.0)
# 2021-07-15 09:38:40.293853: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:3 with 37850 MB memory) -> physical GPU (device: 3, name: A100-SXM4-40GB, pci bus id: 0000:4e:00.0, compute capability: 8.0)
# 2021-07-15 09:38:40.295918: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:4 with 37850 MB memory) -> physical GPU (device: 4, name: A100-SXM4-40GB, pci bus id: 0000:87:00.0, compute capability: 8.0)
# 2021-07-15 09:38:40.297997: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:5 with 37850 MB memory) -> physical GPU (device: 5, name: A100-SXM4-40GB, pci bus id: 0000:90:00.0, compute capability: 8.0)
# 2021-07-15 09:38:40.300069: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:6 with 37850 MB memory) -> physical GPU (device: 6, name: A100-SXM4-40GB, pci bus id: 0000:b7:00.0, compute capability: 8.0)
# 2021-07-15 09:38:40.302144: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:7 with 37850 MB memory) -> physical GPU (device: 7, name: A100-SXM4-40GB, pci bus id: 0000:bd:00.0, compute capability: 8.0)
# 2021-07-15 09:38:40.641189: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245740000 Hz
# 2021-07-15 09:38:41.547812: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2021-07-15 09:38:42.255403: E tensorflow/stream_executor/cuda/cuda_dnn.cc:364] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# 2021-07-15 09:38:42.279092: E tensorflow/stream_executor/cuda/cuda_dnn.cc:364] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# ~/miniconda3/envs/P39/lib/python3.9/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1374     try:
# -> 1375       return fn(*args)
#    1376     except errors.OpError as e:
#
# ~/miniconda3/envs/P39/lib/python3.9/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1358       self._extend_graph()
# -> 1359       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
#    1360                                       target_list, run_metadata)
#
# ~/miniconda3/envs/P39/lib/python3.9/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1450                           run_metadata):
# -> 1451     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1452                                             fetch_list, target_list,
#
# UnknownError: 2 root error(s) found.
#   (0) Unknown: Failed to get convolution algorithm. This is probably because cuDNN failed to initialize, so try looking to see if a warning log message was printed above.
# 	 [[{{node MobilenetV2/Conv/Conv2D}}]]
# 	 [[output/_3]]
#   (1) Unknown: Failed to get convolution algorithm. This is probably because cuDNN failed to initialize, so try looking to see if a warning log message was printed above.
# 	 [[{{node MobilenetV2/Conv/Conv2D}}]]
# 0 successful operations.
# 0 derived errors ignored.
#
# During handling of the above exception, another exception occurred:
#
# UnknownError                              Traceback (most recent call last)
# /tmp/ipykernel_3325172/3984160331.py in <module>
#       1 from ai_benchmark import AIBenchmark
#       2 benchmark = AIBenchmark()
# ----> 3 results = benchmark.run()
#
# ~/miniconda3/envs/P39/lib/python3.9/site-packages/ai_benchmark/__init__.py in run(self, precision)
#      61
#      62     def run(self, precision="normal"):
# ---> 63         return run_tests(training=True, inference=True, micro=False, verbose=self.verbose,
#      64                          use_CPU=self.use_CPU, precision=precision, _type="full", start_dir=self.cwd)
#      65
#
# ~/miniconda3/envs/P39/lib/python3.9/site-packages/ai_benchmark/utils.py in run_tests(training, inference, micro, verbose, use_CPU, precision, _type, start_dir)
#     581                             data = loadData(test.type, subTest.getInputDims())
#     582                             time_iter_started = getTimeMillis()
# --> 583                             sess.run(output_, feed_dict={input_: data})
#     584                             inference_time = getTimeMillis() - time_iter_started
#     585                             inference_times.append(inference_time)
#
# ~/miniconda3/envs/P39/lib/python3.9/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     965
#     966     try:
# --> 967       result = self._run(None, fetches, feed_dict, options_ptr,
#     968                          run_metadata_ptr)
#     969       if run_metadata:
#
# ~/miniconda3/envs/P39/lib/python3.9/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1188     # or if the call is a partial run that specifies feeds.
#    1189     if final_fetches or final_targets or (handle and feed_dict_tensor):
# -> 1190       results = self._do_run(handle, final_targets, final_fetches,
#    1191                              feed_dict_tensor, options, run_metadata)
#    1192     else:
#
# ~/miniconda3/envs/P39/lib/python3.9/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1366
#    1367     if handle is None:
# -> 1368       return self._do_call(_run_fn, feeds, fetches, targets, options,
#    1369                            run_metadata)
#    1370     else:
#
# ~/miniconda3/envs/P39/lib/python3.9/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1392                     '\nsession_config.graph_options.rewrite_options.'
#    1393                     'disable_meta_optimizer = True')
# -> 1394       raise type(e)(node_def, op, message)
#    1395
#    1396   def _extend_graph(self):
#
# UnknownError: 2 root error(s) found.
#   (0) Unknown: Failed to get convolution algorithm. This is probably because cuDNN failed to initialize, so try looking to see if a warning log message was printed above.
# 	 [[node MobilenetV2/Conv/Conv2D (defined at home/daniel.haehn/miniconda3/envs/P39/lib/python3.9/site-packages/ai_benchmark/utils.py:238) ]]
# 	 [[output/_3]]
#   (1) Unknown: Failed to get convolution algorithm. This is probably because cuDNN failed to initialize, so try looking to see if a warning log message was printed above.
# 	 [[node MobilenetV2/Conv/Conv2D (defined at home/daniel.haehn/miniconda3/envs/P39/lib/python3.9/site-packages/ai_benchmark/utils.py:238) ]]
# 0 successful operations.
# 0 derived errors ignored.
#
# Original stack trace for 'MobilenetV2/Conv/Conv2D':
#   File "home/daniel.haehn/miniconda3/envs/P39/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "home/daniel.haehn/miniconda3/envs/P39/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "home/daniel.haehn/miniconda3/envs/P39/lib/python3.9/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "home/daniel.haehn/miniconda3/envs/P39/lib/python3.9/site-packages/traitlets/config/application.py", line 845, in launch_instance
#     app.start()
#   File "home/daniel.haehn/miniconda3/envs/P39/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 667, in start
#     self.io_loop.start()
#   File "home/daniel.haehn/miniconda3/envs/P39/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "home/daniel.haehn/miniconda3/envs/P39/lib/python3.9/asyncio/base_events.py", line 596, in run_forever
#     self._run_once()
#   File "home/daniel.haehn/miniconda3/envs/P39/lib/python3.9/asyncio/base_events.py", line 1890, in _run_once
#     handle._run()
#   File "home/daniel.haehn/miniconda3/envs/P39/lib/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "home/daniel.haehn/miniconda3/envs/P39/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 456, in dispatch_queue
#     await self.process_one()
#   File "home/daniel.haehn/miniconda3/envs/P39/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 445, in process_one
#     await dispatch(*args)
#   File "home/daniel.haehn/miniconda3/envs/P39/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 352, in dispatch_shell
#     await result
#   File "home/daniel.haehn/miniconda3/envs/P39/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 647, in execute_request
#     reply_content = await reply_content
#   File "home/daniel.haehn/miniconda3/envs/P39/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 345, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "home/daniel.haehn/miniconda3/envs/P39/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 532, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "home/daniel.haehn/miniconda3/envs/P39/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2898, in run_cell
#     result = self._run_cell(
#   File "home/daniel.haehn/miniconda3/envs/P39/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2944, in _run_cell
#     return runner(coro)
#   File "home/daniel.haehn/miniconda3/envs/P39/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "home/daniel.haehn/miniconda3/envs/P39/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "home/daniel.haehn/miniconda3/envs/P39/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3361, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "home/daniel.haehn/miniconda3/envs/P39/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3441, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "tmp/ipykernel_3325172/3984160331.py", line 3, in <module>
#     results = benchmark.run()
#   File "home/daniel.haehn/miniconda3/envs/P39/lib/python3.9/site-packages/ai_benchmark/__init__.py", line 63, in run
#     return run_tests(training=True, inference=True, micro=False, verbose=self.verbose,
#   File "home/daniel.haehn/miniconda3/envs/P39/lib/python3.9/site-packages/ai_benchmark/utils.py", line 557, in run_tests
#     input_, output_, train_vars_ = getModelSrc(test, testInfo, sess)
#   File "home/daniel.haehn/miniconda3/envs/P39/lib/python3.9/site-packages/ai_benchmark/utils.py", line 238, in getModelSrc
#     tf.compat.v1.train.import_meta_graph(test.model_src, clear_devices=True)
#   File "home/daniel.haehn/miniconda3/envs/P39/lib/python3.9/site-packages/tensorflow/python/training/saver.py", line 1465, in import_meta_graph
#     return _import_meta_graph_with_return_elements(meta_graph_or_file,
#   File "home/daniel.haehn/miniconda3/envs/P39/lib/python3.9/site-packages/tensorflow/python/training/saver.py", line 1486, in _import_meta_graph_with_return_elements
#     meta_graph.import_scoped_meta_graph_with_return_elements(
#   File "home/daniel.haehn/miniconda3/envs/P39/lib/python3.9/site-packages/tensorflow/python/framework/meta_graph.py", line 801, in import_scoped_meta_graph_with_return_elements
#     imported_return_elements = importer.import_graph_def(
#   File "home/daniel.haehn/miniconda3/envs/P39/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py", line 535, in new_func
#     return func(*args, **kwargs)
#   File "home/daniel.haehn/miniconda3/envs/P39/lib/python3.9/site-packages/tensorflow/python/framework/importer.py", line 400, in import_graph_def
#     return _import_graph_def_internal(
#   File "home/daniel.haehn/miniconda3/envs/P39/lib/python3.9/site-packages/tensorflow/python/framework/importer.py", line 513, in _import_graph_def_internal
#     _ProcessNewOps(graph)
#   File "home/daniel.haehn/miniconda3/envs/P39/lib/python3.9/site-packages/tensorflow/python/framework/importer.py", line 243, in _ProcessNewOps
#     for new_op in graph._add_new_tf_operations(compute_devices=False):  # pylint: disable=protected-access
#   File "home/daniel.haehn/miniconda3/envs/P39/lib/python3.9/site-packages/tensorflow/python/framework/ops.py", line 3707, in _add_new_tf_operations
#     new_ops = [
#   File "home/daniel.haehn/miniconda3/envs/P39/lib/python3.9/site-packages/tensorflow/python/framework/ops.py", line 3708, in <listcomp>
#     self._create_op_from_tf_operation(c_op, compute_device=compute_devices)
#   File "home/daniel.haehn/miniconda3/envs/P39/lib/python3.9/site-packages/tensorflow/python/framework/ops.py", line 3590, in _create_op_from_tf_operation
#     ret = Operation(c_op, self)
#   File "home/daniel.haehn/miniconda3/envs/P39/lib/python3.9/site-packages/tensorflow/python/framework/ops.py", line 2045, in __init__
#     self._traceback = tf_stack.extract_stack_for_node(self._c_op)
